# %%
import pandas as pd

data = {
  "Duration": [50, 40, 45],
  "Pulse": [109, 117, 110],
  "Calories": [409.1, 479.5, 340.8]
}

df = pd.DataFrame(data)

print(df.corr())
# Out:
#           Duration     Pulse  Calories
# Duration  1.000000 -0.917663 -0.507551
# Pulse    -0.917663  1.000000  0.808134
# Calories -0.507551  0.808134  1.000000

# %%
# %pip install autoviz==0.0.6
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/11.7 MB ? eta -:--:--
#    -------------------------- ------------- 7.6/11.7 MB 36.2 MB/s eta 0:00:01
#    ---------------------------------------- 11.7/11.7 MB 31.7 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/13.2 MB ? eta -:--:--
#    ---------------------------------------  13.1/13.2 MB 63.3 MB/s eta 0:00:01
#    ---------------------------------------- 13.2/13.2 MB 51.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 44.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 9.6/9.6 MB 49.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 36.6 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
nr_indice_satisfacao = pd.Series([7, 3, 1, 5, 7, 6, 9, 9])

nr_indice_satisfacao.describe()
# Out:
# count    8.000000
# mean     5.875000
# std      2.799872
# min      1.000000
# 25%      4.500000
# 50%      6.500000
# 75%      7.500000
# max      9.000000
# dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
 
# Gerando um DataFrame de exemplo com vendas de produtos
dados_vendas = {'Produto': ['Smartphone', 'Notebook', 'Fone de Ouvido', 'Smartwatch', 'TV'],
                'Vendas': [120, 85, 45, 60, 150]}
 
df_vendas = pd.DataFrame(dados_vendas)
 
# Criando o histograma
plt.hist(df_vendas['Vendas'], bins=10, rwidth=0.9)
plt.xlabel('Quantidade de Vendas')
plt.ylabel('Frequência')
plt.title('Distribuição de Vendas de Produtos - Melhores Compras')
plt.show()
